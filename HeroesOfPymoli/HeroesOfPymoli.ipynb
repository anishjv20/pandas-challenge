# %%
import pandas as pd

# %%
file_to_load = ("Resources/purchase_data.csv")
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# Player Count###
# Display Total Number of Players

# %%
Player_count = purchase_data["SN"].nunique()
Player_count
# Out:
# 576

# %% [markdown]
# Purchasing Analysis(Total)

# %%
unique_items = purchase_data["Item ID"].nunique()
unique_items
# Out:
# 179

# %%
average_price = purchase_data["Price"].mean()
average_price
# Out:
# 3.050987179487176

# %%
Total_purchase_number = purchase_data["Price"].count()
Total_purchase_number
# Out:
# 780

# %%
Total_revenue = average_price*Total_purchase_number
Total_revenue
# Out:
# 2379.7699999999973

# %%
data = {'Number of Unique Items':[unique_items],'Average Purchase Price':[average_price],'Total Number of Purchases':[Total_purchase_number],'Total Revenue':[Total_revenue]}
purchasing_analysis_df = pd.DataFrame(data)
purchasing_analysis_df
# Out:
#    Number of Unique Items  Average Purchase Price  Total Number of Purchases  \
# 0                     179                3.050987                        780
#
#    Total Revenue
# 0        2379.77

# %%
purchasing_analysis_df["Average Purchase Price"] = purchasing_analysis_df["Average Purchase Price"].astype(float).map("${:.2f}".format)
purchasing_analysis_df["Total Revenue"] = purchasing_analysis_df["Total Revenue"].astype(float).map("${:,.2f}".format)
purchasing_analysis_df
# Out:
#    Number of Unique Items Average Purchase Price  Total Number of Purchases  \
# 0                     179                  $3.05                        780
#
#   Total Revenue
# 0     $2,379.77

# %% [markdown]
# ###Gender Demographics

# %%
male_df = purchase_data.loc[purchase_data["Gender"] == "Male",:]
male_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
male_count = male_df["SN"].nunique()
male_count
# Out:
# 484

# %%
female_df = purchase_data.loc[purchase_data["Gender"] == "Female",:]
female_df.head()
# Out:
#     Purchase ID         SN  Age  Gender  Item ID  \
# 15           15  Lisassa64   21  Female       98
# 18           18  Reunasu60   22  Female       82
# 38           38   Reulae52   10  Female      116
# 41           41  Assosia88   20  Female        7
# 55           55  Phaelap26   25  Female       84
#
#                        Item Name  Price
# 15   Deadline, Voice Of Subtlety   2.89
# 18                       Nirvana   4.90
# 38       Renewed Skeletal Katana   4.18
# 41  Thorn, Satchel of Dark Souls   1.33
# 55                    Arcane Gem   3.79

# %%
female_count = female_df["SN"].nunique()
female_count
# Out:
# 81

# %%
other_df = purchase_data.loc[purchase_data["Gender"] == "Other / Non-Disclosed",:]
other_df.head()
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
#
#                         Item Name  Price
# 9    Ghastly Adamantite Protector   3.58
# 22                  Warped Fetish   3.81
# 82                     Azurewrath   4.40
# 111                         Orbit   4.75
# 228                     Dreamsong   3.39

# %%
other_count = other_df["SN"].nunique()
other_count
# Out:
# 11

# %%
male_percent = (male_count/(male_count+female_count+other_count))*100
female_percent = (female_count/(male_count+female_count+other_count))*100
other_percent = (other_count/(male_count+female_count+other_count))*100

# %%
gender_data = {"":["Male","Female","Other / Non-Disclosed"],"Total Count":[male_count,female_count,other_count],"Percentage of Players":[male_percent,female_percent,other_percent]}
gender_df = pd.DataFrame(gender_data)
gender_df
# Out:
#                           Total Count  Percentage of Players
# 0                   Male          484              84.027778
# 1                 Female           81              14.062500
# 2  Other / Non-Disclosed           11               1.909722

# %%
gender_df = gender_df.set_index("")
gender_df["Percentage of Players"] = gender_df["Percentage of Players"].astype(float).map("{:.2f}%".format)
gender_df
# Out:
#                        Total Count Percentage of Players
#
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ###Purchasing Analysis(Gender)

# %%
gender_group = purchase_data.groupby(['Gender'])
gender_count = gender_group["Purchase ID"].count()

# %%
average_purchase_price = gender_group['Price'].mean()
Total_purchase_value = gender_group['Price'].sum()

# %%
average_purchase_price_per_person_male = Total_purchase_value['Male']/male_count
average_purchase_price_per_person_female = Total_purchase_value['Female']/female_count
average_purchase_price_per_person_other = Total_purchase_value['Other / Non-Disclosed']/other_count

# %%
purchase_analysis_gender_df = pd.DataFrame({
    "Purchase Count": gender_count,"Average Purchase Price": average_purchase_price,"Total Purchase Value": Total_purchase_value,"Avg Total Purchase per Person": [average_purchase_price_per_person_female,average_purchase_price_per_person_male,average_purchase_price_per_person_other]
})
purchase_analysis_gender_df["Average Purchase Price"] = purchase_analysis_gender_df["Average Purchase Price"].astype(float).map("${:.2f}".format)
purchase_analysis_gender_df["Total Purchase Value"] = purchase_analysis_gender_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)
purchase_analysis_gender_df["Avg Total Purchase per Person"] = purchase_analysis_gender_df["Avg Total Purchase per Person"].astype(float).map("${:.2f}".format)
purchase_analysis_gender_df
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ###Age Demographics

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
purchase_unique = purchase_data.drop_duplicates('SN',keep='first')
purchase_unique
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male       92
# 775          775     Aethedru70   21  Female       60
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 773              Pursuit, Cudgel of Necromancy   1.02
# 774                               Final Critic   4.19
# 775                                       Wolf   3.54
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
#
# [576 rows x 7 columns]

# %%
bins = [0,9,14,19,24,29,34,39,47]
group_labels = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]
purchase_unique["Age group"] = pd.cut(purchase_unique["Age"],bins,labels = group_labels)
purchase_unique.head()
# Out:
# C:\Users\anish\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %% [markdown]
# ### Age Demographics

# %%
age_group = purchase_unique.groupby("Age group")["Age"].count().reset_index()
age_group = age_group.rename(columns = {"Age":"Total count"})
age_group["Percentage of Players"] = 100*age_group["Total count"]/age_group["Total count"].sum()
age_group["Percentage of Players"] = age_group["Percentage of Players"].astype(float).map("{:.2f}%".format)
age_group.set_index("Age group")
# Out:
#            Total count Percentage of Players
# Age group
# <10                 17                 2.95%
# 10-14               22                 3.82%
# 15-19              107                18.58%
# 20-24              258                44.79%
# 25-29               77                13.37%
# 30-34               52                 9.03%
# 35-39               31                 5.38%
# 40+                 12                 2.08%

# %% [markdown]
# ### Purchasing Analysis (Age)

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
bins = [0,9,14,19,24,29,34,39,47]
group_labels = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]
purchase_data["Age group"] = pd.cut(purchase_data["Age"],bins,labels = group_labels)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %%
pdc = purchase_data.groupby("Age group")["SN"].count()
pdc = pdc.reset_index()
pdc = pdc.rename(columns = {"SN":"Purchase Count"})
pdc
# Out:
#   Age group  Purchase Count
# 0       <10              23
# 1     10-14              28
# 2     15-19             136
# 3     20-24             365
# 4     25-29             101
# 5     30-34              73
# 6     35-39              41
# 7       40+              13

# %%
app = purchase_data.groupby("Age group")["Price"].mean()
app = app.reset_index()
app["Price"] = app["Price"].map("${:.2f}".format)
app
# Out:
#   Age group  Price
# 0       <10  $3.35
# 1     10-14  $2.96
# 2     15-19  $3.04
# 3     20-24  $3.05
# 4     25-29  $2.90
# 5     30-34  $2.93
# 6     35-39  $3.60
# 7       40+  $2.94

# %%
avg_price_group = purchase_unique.groupby("Age group")["Price"].mean().reset_index()
avg_price_group = avg_price_group.rename(columns = {"Price":"Average Purchase Price"})
avg_price_group
# Out:
#   Age group  Average Purchase Price
# 0       <10                3.390000
# 1     10-14                3.074545
# 2     15-19                3.101682
# 3     20-24                3.063527
# 4     25-29                2.908182
# 5     30-34                2.921538
# 6     35-39                3.510000
# 7       40+                3.037500

# %%
tpv_group = purchase_unique.groupby("Age group")["Price"].sum().reset_index()
tpv_group = tpv_group.rename(columns = {"Price":"Total Purchase Value"})
tpv_group
# Out:
#   Age group  Total Purchase Value
# 0       <10                 57.63
# 1     10-14                 67.64
# 2     15-19                331.88
# 3     20-24                790.39
# 4     25-29                223.93
# 5     30-34                151.92
# 6     35-39                108.81
# 7       40+                 36.45

# %%
age_demographics_group = pd.merge([age_group],[avg_price_group])
age_demographics_group
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-231-de0914900788> in <module>
# ----> 1 age_demographics_group = pd.merge([age_group],[avg_price_group])
#       2 age_demographics_group
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     569         validate=None,
#     570     ):
# --> 571         _left = _validate_operand(left)
#     572         _right = _validate_operand(right)
#     573         self.left = self.orig_left = _left
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in _validate_operand(obj)
#    2006         raise TypeError(
#    2007             "Can only merge Series or DataFrame objects, "
# -> 2008             "a {obj} was passed".format(obj=type(obj))
#    2009         )
#    2010
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'list'> was passed

# %%
purchase_group = purchase_group.set_index("Age group")
purchase_group
# Out:
#            Age  Percentage
# Age group
# <10         17    2.951389
# 10-14       22    3.819444
# 15-19      107   18.576389
# 20-24      258   44.791667
# 25-29       77   13.368056
# 30-34       52    9.027778
# 35-39       31    5.381944
# 40+         12    2.083333

# %%
purchase_group["Average Purchase Price"] = purchase_unique[""]

# %%
purchase_group = purchase_group.rename(columns = {"Age group":"Age","Age":"Total count","Percentage":"Percentage of Players"})
purchase_group
# Out:
#            Total count  Percentage of Players
# Age group
# <10                 17               2.951389
# 10-14               22               3.819444
# 15-19              107              18.576389
# 20-24              258              44.791667
# 25-29               77              13.368056
# 30-34               52               9.027778
# 35-39               31               5.381944
# 40+                 12               2.083333
